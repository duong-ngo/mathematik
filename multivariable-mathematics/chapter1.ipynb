# %% [markdown]
# # Chapter 1. VECTORS AND MATRICES

# %% [markdown]
# ## 1. VECTORS IN $\mathbb{R}^{n}$

# %% [markdown]
# ## 2. DOT PRODUCT

# %% [markdown]
# ## 3. SUBSPACES OF $\mathbb{R}^{n}$

# %% [markdown]
# ## 4. LINEAR TRANSFORMATIONS AND MATRIX ALGEBRA

# %% [markdown]
# ## 5. INTRODUCTION TO DETERMINANTS AND THE CROSS PRODUCT
